# %% [markdown]
# ### Transcript ingestion and standardisation
#
# Bulk ingestion of PDF transcript files in a location - e.g. Batch 1

# %% [markdown]
# NB: Assuming all transcripts are in the most common file format:
#
#    - Front page is copyright info etc.
#        - This is omitted at least once - add detection step
#    - Metadata (interviewee name and regiment, date and name of transcriber)
#    - Tables (from MS Word) with time stamps, text (bold indicating interviewer speaking), highlighted sections marking film breaks
#    - Footers (Legasee information)

# %%
from os import path, listdir
import pandas as pd
import fitz

# %%
# %cd '/home/tompickard/MiniProject/Legasee-Oral-History/'

from transcript_ingestion import page_to_ts, fancy_page_to_ts, text_to_ts
# Out:
# /home/tompickard/MiniProject/Legasee-Oral-History

# %%
# Set target folder for inputs
IN_FOLDER = '~/H_Drive/srv/studat/cdt/data/legasee/navy_veteran_transcripts'

IN_FOLDER = path.expanduser(IN_FOLDER)

# %%
# Set location for metadata, outputs
TARGET_FOLDER = '~/H_Drive/srv/studat/cdt/team2/data/legasee'

TARGET_FOLDER = path.expanduser(TARGET_FOLDER)

# %% [markdown]
# Check for existence of input and output folders (and interrupt if missing)

# %%
assert path.exists(IN_FOLDER)

# %%
assert path.exists(TARGET_FOLDER+'/metadata')
assert path.exists(TARGET_FOLDER+'/test')
assert path.exists(TARGET_FOLDER+'/train')
# Unallocated folder for transcripts of interviews for which we do not (yet) have audio
assert path.exists(TARGET_FOLDER+'/unallocated')

# %% [markdown]
# Read metadata

# %%
meta_df = pd.read_csv(TARGET_FOLDER+'/metadata/'+'master_metadata.csv', converters={'Priority Words': eval, 'Name Words' : eval})

# %%
# Cut down to this specific batch
BATCH_NO = 1

meta_df = meta_df[meta_df.Batch == BATCH_NO]

# %%
meta_df
# Out:
#         id                    Title  Batch  Transcript  Allocation  Content  \
# 0   2643.0  Admiral William O'Brien      1           1  Train/Eval      NaN
# 1   2071.0               Alex Owens      1           1        Test      NaN
# 2   2301.0       Cornelius Snelling      1           1  Train/Eval      NaN
# 3   3238.0              David Craig      1           1  Train/Eval      NaN
# 4   2146.0         Dennis Whitehead      1           1  Train/Eval      NaN
# 5   2252.0                Dick West      1           1  Train/Eval      NaN
# 6   2242.0             Doug Shelley      1           1  Train/Eval      NaN
# 7   2511.0              Eric Conway      1           1  Train/Eval      NaN
# 8   2623.0             Gladys Yates      1           1  Train/Eval      NaN
# 9   2573.0            Gordon Hooton      1           1        Test      NaN
# 10  2374.0            Irene Bellamy      1           1        Test      NaN
# 11  2547.0               Jim Dimond      1           1  Train/Eval      NaN
# 12  3062.0            Joan Endersby      1           1  Train/Eval      NaN
# 13  2536.0               Joan Field      1           1        Test      NaN
# 14  2410.0              Joe Pitcher      1           1        Test      NaN
# 15  1465.0            John Woodward      1           1        Test      NaN
# 16     NaN               Joy Aylard      1           1  Train/Eval      NaN
# 17  2523.0               Megan Moir      1           1  Train/Eval      NaN
# 18  4429.0          Patricia Davies      1           1  Train/Eval      NaN
# 19  1513.0          Patricia Parker      1           1  Train/Eval      NaN
# 20  1545.0            Rodney Newham      1           1        Test      NaN
# 21  1563.0               Stan Hoare      1           1  Train/Eval      NaN
# 22  2021.0                 Vic Ould      1           1        Test      NaN
# 23  2125.0             Albert Owing      1           0         NaN      NaN
# 24  2178.0            Alfred Fowler      1           0         NaN      NaN
# 25     NaN            Betty Sinnott      1           0         NaN      NaN
# 26  2060.0           Bill Churchill      1           0         NaN      NaN
# 27  3025.0          Bill Fellingham      1           0         NaN      NaN
# 28  2165.0         Charles Chirgwin      1           0         NaN      NaN
# 29     NaN        Deirdrie Thompson      1           0         NaN      NaN
# 30     NaN          Denise Harrison      1           0         NaN      NaN
# 31  2156.0           Dorothy Brewer      1           0         NaN      NaN
# 32  2212.0             Edward Wells      1           0         NaN      NaN
# 33  2386.0           Ernest Edwards      1           0         NaN      NaN
# 34     NaN           Evelyn Lintott      1           0         NaN      NaN
# 35  2094.0            Frank Garbutt      1           0         NaN      NaN
# 36  2349.0              Fred Estall      1           0         NaN      NaN
# 37  3249.0            Geoff Shelton      1           0         NaN      NaN
# 38  2138.0             George Floyd      1           0         NaN      NaN
# 39  2202.0              Harry Allen      1           0         NaN      NaN
# 40  3038.0             Jack Madders      1           0         NaN      NaN
# 41  2104.0              Jack Thomas      1           0         NaN      NaN
# 42  2188.0              James Pitts      1           0         NaN      NaN
# 43  3270.0              Jean Watson      1           0         NaN      NaN
# 44  2563.0              Joan Manuel      1           0         NaN      NaN
# 45  2338.0             John Edwards      1           0         NaN      NaN
# 46  2661.0              John Seares      1           0         NaN      NaN
# 47  2443.0           Jonni Berfield      1           0         NaN      NaN
# 48  2288.0           Margery Draper      1           0         NaN      NaN
# 49  2453.0               Pat Jarvis      1           0         NaN      NaN
# 50     NaN              Sidney Ives      1           0         NaN      NaN
# 51  2229.0          William Jenkins      1           0         NaN      NaN
#
#                                              biografy  vimeo_promo_id  \
# 0   A remarkable interview, full of detail and opi...     116177529.0
# 1   The delightful Alex Owens provides a classic s...      90101380.0
# 2   Cornelius Snelling served on the Black Swan-cl...      93458542.0
# 3   David's interview isn't the easiest to listen ...     121183947.0
# 4   Dennis Whitehead served on the C-Class Destroy...      90098682.0
# 5   Dick West gives a brilliant account of his lif...      93459693.0
# 6   Doug is a proud Chatham Rating who experiences...      93459244.0
# 7   Eric Conway provides a fantastic interview det...     100918175.0
# 8   We met Gladys when she visited the Luton prima...     109471660.0
# 9   Gordon ran away from home and the Navy and the...             NaN
# 10  Irene Bellamy provides an entertaining and det...     100237326.0
# 11                                                NaN     107398593.0
# 12  Joan gives an interview that's full of fun and...     116178110.0
# 13  Joan Field was a WREN stationed at an extraord...     107398595.0
# 14  Joe Pitcher was a DEMS gunner on many Merchant...      97151742.0
# 15  John Woodward worked on a Minesweeper during W...      72025251.0
# 16  Joyce Aylard was stationed at HMS Pembroke V i...             NaN
# 17  Megan Moir was a Wren Writer onboard the exerc...     100918323.0
# 18  Patricia Davies provides a great interview det...     125687860.0
# 19  Patricia Parker was a WREN based at HMS Ceres ...      90101408.0
# 20  Rodney Newham lives in the RNBT’s Pembroke Hou...      90101415.0
# 21  Thanks to the Royal Navy's 'Pembroke House' fo...      90101418.0
# 22  Vic Ould gives a fascinating account of his li...      84855907.0
# 23  Albert Owing was a Merchant Seaman who sailed ...      90101375.0
# 24  Some fascinating detail about HMS Sheffield in...      93458233.0
# 25                                                NaN             NaN
# 26  Bill Churchill provides a detailed account of ...      90101386.0
# 27                                                NaN     116178661.0
# 28  RMS Queen Elizabeth was one of the very first ...      93458312.0
# 29                                                NaN             NaN
# 30                                                NaN             NaN
# 31  Dorothy Brewer was an Aircraft Fitter with the...      90101391.0
# 32  Ted Wells provides a fascinating account of hi...     425917595.0
# 33  Ernest Edwards gives an interesting account of...     103981797.0
# 34                                                NaN             NaN
# 35  Frank Garbutt was the Quartermaster on the air...      90101396.0
# 36  Fred Estall gives a good account of his life a...      97151741.0
# 37                                                NaN             NaN
# 38  George Floyd was a [LSA ] Leading Stores Assis...      90098683.0
# 39  Harry Allen was a boy sailor when he joined HM...      93460950.0
# 40                                                NaN     116178461.0
# 41  Jack Thomas provides a brilliant account of hi...      90101407.0
# 42  James Pitts provides a fascinating and detaile...      93461282.0
# 43  Jean Watson gives a good account of her time i...             NaN
# 44  Joan Manuel provides an entertaining account o...     107398592.0
# 45  John Edwards gives a great account of his 5 ye...      93460272.0
# 46  John Seares talks in detail about his service ...     116177876.0
# 47  Jonni Berfield was a coder for the Royal Navy....     100389444.0
# 48  Margery gives an outstanding account of her wa...     103981794.0
# 49  When war broke out there was only ever going t...     100043007.0
# 50                                                NaN             NaN
# 51  William Jenkins gives a true sailors account o...      93485906.0
#
#                                     vimeo_description Service Types  \
# 0   On PQ 17: "I can remember vividly the scene at...          Navy
# 1                                                 NaN          Navy
# 2   Cornelius Snelling served on the Black Swan-cl...          Navy
# 3   David Craig provides a fantastic account of hi...      Civilian
# 4   It’s hard to determine if it was good or bad l...          Navy
# 5   Dick West gives a brilliant account of his lif...          Navy
# 6   Doug was a man with many friends in the Royal ...          Navy
# 7   Second World War Submariners are a rare find. ...          Navy
# 8   In this extract from her interview, Gladys rec...          Navy
# 9                                                 NaN          Navy
# 10                                                NaN          Navy
# 11  Jim Dimond joined the Royal Navy in 1942. He h...          Navy
# 12  One of the most hilarious interviews I've ever...          Navy
# 13  "I got this rifle and I knew it wasn't loaded ...          Navy
# 14  In this short extract from his interview, Joe ...          Navy
# 15  In this short extract from his interview, John...          Navy
# 16  Such was the level of secrecy at the time, Joy...           NaN
# 17  In this short extract from her interview, Mega...          Navy
# 18  Patricia recalls, "If it was in code, and a lo...          Navy
# 19                                                NaN          Navy
# 20  Rodney details some of his work at the Chatham...      Civilian
# 21  Stan told us, "we lined up on the quarter deck...          Navy
# 22                                                NaN          Navy
# 23                                                NaN          Navy
# 24  Alfred ‘Chick’ Fowler gives a very detailed ac...          Navy
# 25                                                NaN           NaN
# 26  Bill provided a wonderful interview of his tim...          Navy
# 27  Bill Fellingham provides a detailed account of...      Civilian
# 28  Charles Chirgwin provides a fascinating accoun...          Navy
# 29                                                NaN           NaN
# 30                                                NaN           NaN
# 31  Dorothy's character shines through in the shor...          Navy
# 32  A short extract from his great interview. Sixt...          Navy
# 33         An emotional account of a civilian in war.      Civilian
# 34                                                NaN           NaN
# 35                                                NaN          Navy
# 36                                                NaN          Navy
# 37  Geoff was an Able Seaman aboard the aircraft c...          Navy
# 38                                                NaN          Navy
# 39                                                NaN          Navy
# 40  Jack Madders provides a fabulously detailed ac...          Navy
# 41  You know you're in the presence of someone wit...          Navy
# 42                                                NaN          Navy
# 43  Jean Watson gives a good account of her time i...          Navy
# 44  In this short extract from her interview, Joan...          Navy
# 45  John Edwards gives a great account of his 5 ye...      Civilian
# 46  In this short extract from his interview, John...          Navy
# 47     Jonni also appeared on the Great British Menu!          Navy
# 48  "Margery recalls the Devonport blitz, "we saw ...          Navy
# 49  In this short extract from her interview, Pat ...          Navy
# 50                                                NaN           NaN
# 51  In true sailors language, William recalls the ...          Navy
#
#                                         Project Types  \
# 0   The Veterans' video archive|Keeping Britain Af...
# 1   Keeping Britain Afloat|The Veterans' video arc...
# 2   The Normandy Campaign|The Veterans' video arch...
# 3   The Veterans' video archive|Keeping Britain Af...
# 4   Keeping Britain Afloat|The Veterans' video arc...
# 5   Keeping Britain Afloat|The Veterans' video arc...
# 6   The Veterans' video archive|Keeping Britain Af...
# 7   Keeping Britain Afloat|The Veterans' video arc...
# 8   The Veterans' video archive|Keeping Britain Af...
# 9   Keeping Britain Afloat|The Veterans' video arc...
# 10  The Secret War|The Veterans' video archive|Kee...
# 11  The Veterans' video archive|Keeping Britain Af...
# 12  The Veterans' video archive|Keeping Britain Af...
# 13  The Veterans' video archive|Keeping Britain Af...
# 14  The Veterans' video archive|Keeping Britain Af...
# 15  The Veterans' video archive|Keeping Britain Af...
# 16                                                NaN
# 17  Keeping Britain Afloat|The Veterans' video arc...
# 18  The Secret War|Keeping Britain Afloat|The Vete...
# 19  The Veterans' video archive|Keeping Britain Af...
# 20  The Veterans' video archive|Keeping Britain Af...
# 21  Keeping Britain Afloat|The Veterans' video arc...
# 22  Keeping Britain Afloat|The Veterans' video arc...
# 23  Keeping Britain Afloat|The Veterans' video arc...
# 24  Keeping Britain Afloat|The Veterans' video arc...
# 25                                                NaN
# 26  Keeping Britain Afloat|The Veterans' video arc...
# 27  The Veterans' video archive|Keeping Britain Af...
# 28  The Veterans' video archive|Keeping Britain Af...
# 29                                                NaN
# 30                                                NaN
# 31  The Veterans' video archive|Keeping Britain Af...
# 32  The Veterans' video archive|Keeping Britain Af...
# 33  The Veterans' video archive|Keeping Britain Af...
# 34                                                NaN
# 35  The Veterans' video archive|Keeping Britain Af...
# 36  The Veterans' video archive|Keeping Britain Af...
# 37  The Veterans' video archive|Keeping Britain Af...
# 38  The Veterans' video archive|Keeping Britain Af...
# 39  The Veterans' video archive|Keeping Britain Af...
# 40  The Veterans' video archive|Keeping Britain Af...
# 41  Keeping Britain Afloat|The Veterans' video arc...
# 42  Keeping Britain Afloat|The Veterans' video arc...
# 43  Keeping Britain Afloat|The Secret War|The Vete...
# 44  Keeping Britain Afloat|The Veterans' video arc...
# 45                             Keeping Britain Afloat
# 46  Keeping Britain Afloat|The Veterans' video arc...
# 47  The Veterans' video archive|Keeping Britain Af...
# 48  The Veterans' video archive|Keeping Britain Af...
# 49  The Veterans' video archive|Keeping Britain Af...
# 50                                                NaN
# 51  The Veterans' video archive|Keeping Britain Af...
#
#                                                  Tags  \
# 0   Places>North Africa|Role>First Lieutenant|Role...
# 1   Places>England - HMS Ganges (Stone Frigate)|Mi...
# 2   Miscellaneous>Naval - Rum Ration|Battles>Opera...
# 3   Places>Russia|Miscellaneous>Naval Convoy - JW5...
# 4   Service Type>Navy|Role>Ordinary Seaman|Places>...
# 5   Miscellaneous>Naval - Action Stations|Miscella...
# 6   Places>Australia|Role>Chatham Rating|Role>Able...
# 7   Miscellaneous>Description - Job Role|Vehicles>...
# 8   Service Type>Womens Royal Naval Service|Role>W...
# 9   Places>Russia|Places>Russia - Polyarny|Places>...
# 10  Places>Normandy - Granville|Miscellaneous>Meda...
# 11  Vehicles>U-Boat - U414|Places>Canada|Miscellan...
# 12  Miscellaneous>Training|Role>Teleprinter Operat...
# 13  Vehicles>Southern Wave|Miscellaneous>Descripti...
# 14  Role>DEMS Gunner|Vehicles>HMS Kenrix|Role>Chat...
# 15  Battles>Operation - Neptune / Overlord (D-Day)...
# 16  War/Conflict>WWII|Places>England - London ( Ea...
# 17  Places>England - Burscough|War/Conflict>WWII|R...
# 18  Miscellaneous>POW - Red Cross Parcels|Miscella...
# 19  Miscellaneous>Royal Naval Benevolent Trust|Mis...
# 20  Miscellaneous>Servicing - Maintenance|Miscella...
# 21  Miscellaneous>Incident|Role>Ordinary Seaman|Ro...
# 22  Places>Scotland - HMS Scotia (Stone Frigate)|P...
# 23  Vehicles>RFA Diligence|Vehicles>MV Highland Br...
# 24  Miscellaneous>Training - Basic / Initial|Role>...
# 25                                                NaN
# 26  Role>Torpedoman Writer|Battles>Operation - Dyn...
# 27                                                NaN
# 28  Places>Wales - Cardiff|Places>America - New Yo...
# 29                                                NaN
# 30                                                NaN
# 31  Vehicles>Grumman - Hellcat|Vehicles>Grumman - ...
# 32  Miscellaneous>Incident - Ship Sank|Vehicles>HM...
# 33  Battles>Operation - Neptune / Overlord (D-Day)...
# 34                                                NaN
# 35  Miscellaneous>Naval - Action Stations|Battles>...
# 36  Miscellaneous>Training - Basic / Initial|Battl...
# 37                                                NaN
# 38  Role>Cook|Role>Chatham Rating|War/Conflict>WWI...
# 39  Miscellaneous>Description - Ship / Sub|Places>...
# 40                                                NaN
# 41  Miscellaneous>First - Flight|Vehicles>Fairey S...
# 42  Miscellaneous>Training - Basic / Initial|War/C...
# 43                                                NaN
# 44                                                NaN
# 45  Miscellaneous>First - Ship|Vehicles>MV Trentba...
# 46                                                NaN
# 47  Miscellaneous>Incident|Places>England - Plymou...
# 48  Role>WREN|Role>Steward|Service Type>Womens Roy...
# 49  Miscellaneous>Incident|Miscellaneous>Life - Ch...
# 50                                                NaN
# 51  Service Type>Navy|Vehicles>HMS Arethuse|Vehicl...
#
#                                        related_videos  \
# 0   a:14:{i:0;s:4:"2647";i:1;s:4:"2648";i:2;s:4:"2...
# 1   a:7:{i:0;s:4:"2074";i:1;s:4:"2075";i:2;s:4:"20...
# 2   a:12:{i:0;s:4:"2304";i:1;s:4:"2305";i:2;s:4:"2...
# 3   a:8:{i:0;s:4:"3241";i:1;s:4:"3242";i:2;s:4:"32...
# 4   a:6:{i:0;s:4:"2149";i:1;s:4:"2150";i:2;s:4:"21...
# 5   a:7:{i:0;s:4:"2255";i:1;s:4:"2256";i:2;s:4:"22...
# 6   a:7:{i:0;s:4:"2245";i:1;s:4:"2246";i:2;s:4:"22...
# 7   a:9:{i:0;s:4:"2514";i:1;s:4:"2515";i:2;s:4:"25...
# 8   a:4:{i:0;s:4:"2626";i:1;s:4:"2627";i:2;s:4:"26...
# 9   a:5:{i:0;s:4:"2576";i:1;s:4:"2577";i:2;s:4:"25...
# 10  a:9:{i:0;s:4:"2377";i:1;s:4:"2378";i:2;s:4:"23...
# 11  a:7:{i:0;s:4:"2550";i:1;s:4:"2551";i:2;s:4:"25...
# 12  a:5:{i:0;s:4:"3065";i:1;s:4:"3066";i:2;s:4:"30...
# 13  a:7:{i:0;s:4:"2540";i:1;s:4:"2541";i:2;s:4:"25...
# 14  a:7:{i:0;s:4:"2413";i:1;s:4:"2414";i:2;s:4:"24...
# 15  a:5:{i:0;s:4:"1468";i:1;s:4:"1469";i:2;s:4:"14...
# 16                                                NaN
# 17  a:7:{i:0;s:4:"2526";i:1;s:4:"2527";i:2;s:4:"25...
# 18  a:7:{i:0;s:4:"4433";i:1;s:4:"4434";i:2;s:4:"44...
# 19  a:7:{i:0;s:4:"1516";i:1;s:4:"1517";i:2;s:4:"15...
# 20  a:5:{i:0;s:4:"1548";i:1;s:4:"1549";i:2;s:4:"15...
# 21  a:8:{i:0;s:4:"1567";i:1;s:4:"1568";i:2;s:4:"15...
# 22  a:12:{i:0;s:4:"2024";i:1;s:4:"2025";i:2;s:4:"2...
# 23  a:10:{i:0;s:4:"2128";i:1;s:4:"2129";i:2;s:4:"2...
# 24  a:7:{i:0;s:4:"2181";i:1;s:4:"2182";i:2;s:4:"21...
# 25                                                NaN
# 26  a:8:{i:0;s:4:"2063";i:1;s:4:"2064";i:2;s:4:"20...
# 27  a:10:{i:0;s:4:"3028";i:1;s:4:"3029";i:2;s:4:"3...
# 28  a:10:{i:0;s:4:"2168";i:1;s:4:"2169";i:2;s:4:"2...
# 29                                                NaN
# 30                                                NaN
# 31  a:6:{i:0;s:4:"2159";i:1;s:4:"2160";i:2;s:4:"21...
# 32  a:14:{i:0;s:4:"2215";i:1;s:4:"2216";i:2;s:4:"2...
# 33  a:8:{i:0;s:4:"2389";i:1;s:4:"2390";i:2;s:4:"23...
# 34                                                NaN
# 35  a:7:{i:0;s:4:"2097";i:1;s:4:"2098";i:2;s:4:"20...
# 36  a:7:{i:0;s:4:"2352";i:1;s:4:"2353";i:2;s:4:"23...
# 37  a:6:{i:0;s:4:"3252";i:1;s:4:"3253";i:2;s:4:"32...
# 38  a:5:{i:0;s:4:"2141";i:1;s:4:"2142";i:2;s:4:"21...
# 39  a:7:{i:0;s:4:"2205";i:1;s:4:"2206";i:2;s:4:"22...
# 40  a:11:{i:0;s:4:"3041";i:1;s:4:"3042";i:2;s:4:"3...
# 41  a:10:{i:0;s:4:"2108";i:1;s:4:"2109";i:2;s:4:"2...
# 42  a:11:{i:0;s:4:"2191";i:1;s:4:"2192";i:2;s:4:"2...
# 43  a:4:{i:0;s:4:"3273";i:1;s:4:"3274";i:2;s:4:"32...
# 44  a:7:{i:0;s:4:"2566";i:1;s:4:"2567";i:2;s:4:"25...
# 45  a:8:{i:0;s:4:"2341";i:1;s:4:"2342";i:2;s:4:"23...
# 46  a:7:{i:0;s:4:"2664";i:1;s:4:"2665";i:2;s:4:"26...
# 47  a:7:{i:0;s:4:"2446";i:1;s:4:"2447";i:2;s:4:"24...
# 48  a:9:{i:0;s:4:"2292";i:1;s:4:"2293";i:2;s:4:"22...
# 49  a:7:{i:0;s:4:"2456";i:1;s:4:"2457";i:2;s:4:"24...
# 50                                                NaN
# 51  a:10:{i:0;s:4:"2232";i:1;s:4:"2233";i:2;s:4:"2...
#
#                                        Priority Words  \
# 0   [North Africa, First Lieutenant, Navigator, WW...
# 1   [England, HMS Ganges (Stone Frigate), Descript...
# 2   [Naval, Rum Ration, Operation, Neptune / Overl...
# 3   [Russia, Naval Convoy, JW53, Ship, Russian / A...
# 4   [Navy, Ordinary Seaman, Mil Camp Uk, RNB Chath...
# 5   [Naval, Action Stations, Naval Actions, Naval ...
# 6   [Australia, Chatham Rating, Able Seaman, Naval...
# 7   [Description, Job Role, Submarine, Incident, E...
# 8   [Womens Royal Naval Service, WRNS, Officer Ste...
# 9   [Russia, Russia, Polyarny, The Far East, Russi...
# 10  [Normandy, Granville, Medal, British Empire Me...
# 11  [U-Boat, U414, Canada, Naval Convoy, CAM ship ...
# 12  [Training, Teleprinter Operator, Westfield Col...
# 13  [Southern Wave, Description, Camp / Accom, Des...
# 14  [DEMS Gunner, HMS Kenrix, Chatham Rating, HMS ...
# 15  [Operation, Neptune / Overlord (D-Day), Reserv...
# 16  [WWII, England, London ( Eastcote), WRNS, Bomb...
# 17  [England, Burscough, WWII, WRNS Writer, Womens...
# 18  [POW, Red Cross Parcels, POW, POW, Japanese, V...
# 19  [Royal Naval Benevolent Trust, Social Life, So...
# 20  [Servicing, Maintenance, Servicing, Repair, Sh...
# 21  [Incident, Ordinary Seaman, Radar Operator, Na...
# 22  [Scotland, HMS Scotia (Stone Frigate), Scotlan...
# 23  [RFA Diligence, MV Highland Brigade, Magnetic ...
# 24  [Training, Basic / Initial, Stoker, Ship, Russ...
# 25                                                 []
# 26  [Torpedoman Writer, Operation, Dynamo (Dunkirk...
# 27                                                 []
# 28  [Wales, Cardiff, America, New York, Leading Ra...
# 29                                                 []
# 30                                                 []
# 31  [Grumman, Hellcat, Grumman, F4F Wildcat, Fleet...
# 32  [Incident, Ship Sank, HMS Urchin, Ship, Malta ...
# 33  [Operation, Neptune / Overlord (D-Day), Naval,...
# 34                                                 []
# 35  [Naval, Action Stations, Ship, Russian / Arcti...
# 36  [Training, Basic / Initial, Ship, Russian / Ar...
# 37                                                 []
# 38  [Cook, Chatham Rating, WWII, Ship Duties, Atla...
# 39  [Description, Ship / Sub, Scapa Flow, Naval Co...
# 40                                                 []
# 41  [First, Flight, Fairey Swordfish, England, Dur...
# 42  [Training, Basic / Initial, WWII, VE Day, Firs...
# 43                                                 []
# 44                                                 []
# 45  [First, Ship, MV Trentbank, Incident, Incident...
# 46                                                 []
# 47  [Incident, England, Plymouth, Life, Pre Servic...
# 48  [WREN, Steward, Womens Royal Naval Service, WW...
# 49  [Incident, Life, Childhood, Life, Pre Service,...
# 50                                                 []
# 51  [Navy, HMS Arethuse, HMS Emerald, HMS Musketee...
#
#                      Name Words
# 0   [Admiral, William, O'Brien]
# 1                 [Alex, Owens]
# 2         [Cornelius, Snelling]
# 3                [David, Craig]
# 4           [Dennis, Whitehead]
# 5                  [Dick, West]
# 6               [Doug, Shelley]
# 7                [Eric, Conway]
# 8               [Gladys, Yates]
# 9              [Gordon, Hooton]
# 10             [Irene, Bellamy]
# 11                [Jim, Dimond]
# 12             [Joan, Endersby]
# 13                [Joan, Field]
# 14               [Joe, Pitcher]
# 15             [John, Woodward]
# 16                [Joy, Aylard]
# 17                [Megan, Moir]
# 18           [Patricia, Davies]
# 19           [Patricia, Parker]
# 20             [Rodney, Newham]
# 21                [Stan, Hoare]
# 22                  [Vic, Ould]
# 23              [Albert, Owing]
# 24             [Alfred, Fowler]
# 25             [Betty, Sinnott]
# 26            [Bill, Churchill]
# 27           [Bill, Fellingham]
# 28          [Charles, Chirgwin]
# 29         [Deirdrie, Thompson]
# 30           [Denise, Harrison]
# 31            [Dorothy, Brewer]
# 32              [Edward, Wells]
# 33            [Ernest, Edwards]
# 34            [Evelyn, Lintott]
# 35             [Frank, Garbutt]
# 36               [Fred, Estall]
# 37             [Geoff, Shelton]
# 38              [George, Floyd]
# 39               [Harry, Allen]
# 40              [Jack, Madders]
# 41               [Jack, Thomas]
# 42               [James, Pitts]
# 43               [Jean, Watson]
# 44               [Joan, Manuel]
# 45              [John, Edwards]
# 46               [John, Seares]
# 47            [Jonni, Berfield]
# 48            [Margery, Draper]
# 49                [Pat, Jarvis]
# 50               [Sidney, Ives]
# 51           [William, Jenkins]

# %%
exceptions = {}

# Do not skip the first page of PDF for files in this list - use when copyright frontpage is omitted
INCLUDE_FIRST = ['Catherine_Avent.pdf']

# Process files in IN_FOLDER
for fname in listdir(IN_FOLDER):
    _alloc = None
    
    #  Only want PDFs
    if fname[-4:] != '.pdf':
        pass
    
    else:
        #  Extract name
        pname = fname[:-4].replace('_',' ')
        
        #  Check against metadata
        mdets = meta_df[meta_df.Title == pname]
        #  If no match or more than 1, add to exceptions and report at the end of loop
        if len(mdets) != 1:
            print('{} metadata records found corresponding to {}. Adding to exceptions.'.format(len(mdets),fname))
            exceptions[fname] = 'Metadata'
            
        else:
            _alloc = mdets.reset_index().Allocation[0]
            _batch = mdets.reset_index().Batch[0]
            
            _doc = fitz.open(IN_FOLDER+'/'+fname)
            _transcripts = []
            
            if fname in INCLUDE_FIRST: _start_page = 0
            # Omit first page as it's copyright material / frontispiece, unless instructed otherwise
            else: _start_page = 1
            
            for page in _doc.pages(_start_page):
                try:
                    _transcripts.extend(page_to_ts(page))
                                       
                #  If get an error from the page reading function, move to exceptions
                except:
                    print('Error processing {}. Adding to exceptions.'.format(fname))
                    exceptions[fname] = 'Processing error'
                    break
            
            if fname in exceptions:
                pass
            
            else:
                df = pd.DataFrame(_transcripts,columns = ["Timestamp", "Speaker", "Transcript"])

                # Determine output subfolder
                if _batch < 0: _subfolder = '/unallocated/'
                elif _alloc == "Test": _subfolder = '/test/'
                elif _alloc == 'Train/Eval' : _subfolder = '/train/'
                else:
                    print('Cannot determine output location for {}. Adding to exceptions.'.format(fname))
                    exceptions[fname] = 'Output location'
                    break

                _outname = pname.replace(' ','_')

                df.to_csv(TARGET_FOLDER+_subfolder+'transcripts/'+_outname+'.tsv',
                          sep = '\t'
                         )
# Out:
# 0 metadata records found corresponding to John Roche.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Alan Lloyd.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Mervyn Salter.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Albert Malin.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Pam Torrens.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Alec Penstone.pdf. Adding to exceptions.
# /home/tompickard/MiniProject/Legasee-Oral-History/transcript_ingestion.py:144: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 144 of the file /home/tompickard/MiniProject/Legasee-Oral-History/transcript_ingestion.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   page_bs = BeautifulSoup(raw_html)
# 0 metadata records found corresponding to Alec Pulfer.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Alexander Owens.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Buster Brown.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Catherine_Avent.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Ted Hunt.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Colette Cook.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Ted Rogers.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Lord Alan West.pdf. Adding to exceptions.
# 0 metadata records found corresponding to William O'Brien 1.pdf. Adding to exceptions.
# 0 metadata records found corresponding to William O'Brien.pdf. Adding to exceptions.
# 0 metadata records found corresponding to William Sheppard.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Ernest Kellaway.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Frances McLaren.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Harry Card.pdf. Adding to exceptions.
# 0 metadata records found corresponding to John Harrison.pdf. Adding to exceptions.
# 0 metadata records found corresponding to Joy Aylard Transcript.pdf. Adding to exceptions.

# %%
for k,v in exceptions.items():
    print(k, '\t', v)
# Out:
# John Roche.pdf 	 Metadata
# Alan Lloyd.pdf 	 Metadata
# Mervyn Salter.pdf 	 Metadata
# Albert Malin.pdf 	 Metadata
# Pam Torrens.pdf 	 Metadata
# Alec Penstone.pdf 	 Metadata
# Alec Pulfer.pdf 	 Metadata
# Alexander Owens.pdf 	 Metadata
# Buster Brown.pdf 	 Metadata
# Catherine_Avent.pdf 	 Metadata
# Ted Hunt.pdf 	 Metadata
# Colette Cook.pdf 	 Metadata
# Ted Rogers.pdf 	 Metadata
# Lord Alan West.pdf 	 Metadata
# William O'Brien 1.pdf 	 Metadata
# William O'Brien.pdf 	 Metadata
# William Sheppard.pdf 	 Metadata
# Ernest Kellaway.pdf 	 Metadata
# Frances McLaren.pdf 	 Metadata
# Harry Card.pdf 	 Metadata
# John Harrison.pdf 	 Metadata
# Joy Aylard Transcript.pdf 	 Metadata
